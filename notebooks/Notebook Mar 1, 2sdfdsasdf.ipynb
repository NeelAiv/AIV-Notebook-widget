# %%
asdfg
# Out:
# <div style="color:#ef4444; margin-top:5px;"><strong>Error:</strong> Traceback (most recent call last):
#   File "/lib/python311.zip/_pyodide/_base.py", line 573, in eval_code_async
#     await CodeRunner(
#   File "/lib/python311.zip/_pyodide/_base.py", line 393, in run_async
#     coroutine = eval(self.code, globals, locals)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<exec>", line 1, in <module>
# NameError: name 'asdfg' is not defined
# </module></exec></div>

# %%
sdfg
# Out:
# <div style="color:#ef4444; margin-top:5px;"><strong>Error:</strong> Traceback (most recent call last):
#   File "/lib/python311.zip/_pyodide/_base.py", line 573, in eval_code_async
#     await CodeRunner(
#   File "/lib/python311.zip/_pyodide/_base.py", line 393, in run_async
#     coroutine = eval(self.code, globals, locals)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<exec>", line 1, in <module>
# NameError: name 'sdfg' is not defined
# </module></exec></div>
